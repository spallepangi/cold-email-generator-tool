# %%
pip install langchain
# Out:
# Collecting langchain
#   Using cached langchain-0.3.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain) (3.9.5)
# Collecting langchain-core<0.4.0,>=0.3.0 (from langchain)
#   Using cached langchain_core-0.3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Using cached langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Using cached langsmith-0.1.127-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain) (1.26.4)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain) (2.32.2)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain)
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\santhosh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\santhosh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\santhosh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\santhosh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\santhosh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\santhosh\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\santhosh\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\santhosh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Collecting pydantic-core==2.23.4 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.23.4-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\santhosh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\santhosh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\santhosh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\santhosh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\santhosh\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: anyio in c:\users\santhosh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\santhosh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\santhosh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\santhosh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\santhosh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain) (2.1)
# Using cached langchain-0.3.0-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.5-py3-none-any.whl (399 kB)
# Using cached langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Using cached langsmith-0.1.127-py3-none-any.whl (291 kB)
# Using cached pydantic-2.9.2-py3-none-any.whl (434 kB)
# Downloading pydantic_core-2.23.4-cp312-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.9 MB 495.5 kB/s eta 0:00:04
#    --- ------------------------------------ 0.2/1.9 MB 1.2 MB/s eta 0:00:02
#    -------- ------------------------------- 0.4/1.9 MB 2.2 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/1.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 6.8 MB/s eta 0:00:00
# Using cached tenacity-8.5.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, pydantic-core, pydantic, langsmith, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.14.6
#     Uninstalling pydantic_core-2.14.6:
#       Successfully uninstalled pydantic_core-2.14.6
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.3
#     Uninstalling pydantic-2.5.3:
#       Successfully uninstalled pydantic-2.5.3
# Successfully installed langchain-0.3.0 langchain-core-0.3.5 langchain-text-splitters-0.3.0 langsmith-0.1.127 pydantic-2.9.2 pydantic-core-2.23.4 tenacity-8.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Using cached langchain_groq-0.2.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting groq<1,>=0.4.1 (from langchain-groq)
#   Using cached groq-0.11.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-groq) (0.3.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\santhosh\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\santhosh\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\santhosh\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\santhosh\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (2.9.2)
# Requirement already satisfied: sniffio in c:\users\santhosh\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\santhosh\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.11.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq) (0.1.127)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq) (23.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq) (8.5.0)
# Requirement already satisfied: idna>=2.8 in c:\users\santhosh\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.7)
# Requirement already satisfied: certifi in c:\users\santhosh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\santhosh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\santhosh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\santhosh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain-groq) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\santhosh\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq) (3.10.7)
# Requirement already satisfied: requests<3,>=2 in c:\users\santhosh\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq) (2.32.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\santhosh\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\santhosh\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\santhosh\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\santhosh\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq) (2.2.2)
# Using cached langchain_groq-0.2.0-py3-none-any.whl (14 kB)
# Using cached groq-0.11.0-py3-none-any.whl (106 kB)
# Installing collected packages: groq, langchain-groq
# Successfully installed groq-0.11.0 langchain-groq-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\santhosh\anaconda3\lib\site-packages (0.5.7)
# Requirement already satisfied: build>=1.0.3 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (1.2.2)
# Requirement already satisfied: pydantic>=1.9 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (2.9.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (0.115.0)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\santhosh\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.6)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (3.6.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (4.11.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (4.66.4)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (1.66.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (0.12.5)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (3.10.7)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (13.3.5)
# Requirement already satisfied: packaging>=19.1 in c:\users\santhosh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in c:\users\santhosh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: colorama in c:\users\santhosh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in c:\users\santhosh\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.38.6)
# Requirement already satisfied: anyio in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: certifi in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\santhosh\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.35.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.2)
# Requirement already satisfied: requests-oauthlib in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.2)
# Requirement already satisfied: durationpy>=0.7 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.7)
# Requirement already satisfied: coloredlogs in c:\users\santhosh\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\santhosh\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\santhosh\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in c:\users\santhosh\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\santhosh\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in c:\users\santhosh\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\santhosh\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in c:\users\santhosh\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in c:\users\santhosh\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in c:\users\santhosh\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in c:\users\santhosh\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in c:\users\santhosh\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in c:\users\santhosh\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\santhosh\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (69.5.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\santhosh\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\santhosh\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\santhosh\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\santhosh\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\santhosh\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\santhosh\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.23.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\santhosh\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\santhosh\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\santhosh\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.25.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\santhosh\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\santhosh\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\santhosh\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\santhosh\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\santhosh\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\santhosh\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (13.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\santhosh\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\santhosh\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\santhosh\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\santhosh\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\santhosh\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.3.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\santhosh\anaconda3\lib\site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\santhosh\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\santhosh\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (2.0.4)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\santhosh\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\santhosh\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\santhosh\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\santhosh\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.3.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-community) (3.9.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: langchain<0.4.0,>=0.3.0 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-community) (0.3.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.0 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-community) (0.3.5)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-community) (0.1.127)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.5.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-community) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\santhosh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\santhosh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\santhosh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\santhosh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\santhosh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.0->langchain-community) (0.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.0->langchain-community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-community) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain-community) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\santhosh\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\santhosh\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community) (3.10.7)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\santhosh\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\santhosh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\santhosh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\santhosh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\santhosh\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\santhosh\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.1)
# Requirement already satisfied: anyio in c:\users\santhosh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\santhosh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\santhosh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\santhosh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\santhosh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain-community) (2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\santhosh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.0->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\santhosh\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.0->langchain-community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\santhosh\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Downloading langchain_community-0.3.0-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.3 MB 1.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.2/2.3 MB 2.9 MB/s eta 0:00:01
#    -------- ------------------------------- 0.5/2.3 MB 4.1 MB/s eta 0:00:01
#    --------------- ------------------------ 0.9/2.3 MB 5.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.4/2.3 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 9.3 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading pydantic_settings-2.5.2-py3-none-any.whl (26 kB)
# Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.3 kB ? eta -:--:--
#    ---------------------------------------- 49.3/49.3 kB 2.6 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Installing collected packages: typing-inspect, marshmallow, dataclasses-json, pydantic-settings, langchain-community
# Successfully installed dataclasses-json-0.6.7 langchain-community-0.3.0 marshmallow-3.22.0 pydantic-settings-2.5.2 typing-inspect-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import chromadb

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    temperature=0, 
    groq_api_key='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', 
    model_name="llama-3.1-70b-versatile"
)
response = llm.invoke("The first person to land on moon was ...")
print(response.content)
# Out:
# The first person to land on the moon was Neil Armstrong. He stepped onto the lunar surface on July 20, 1969, as part of the Apollo 11 mission.

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://jobs.nike.com/job/R-38716?from=job%20search%20funnel")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# Apply for Data Engineer, ITC
#
# Search JobsSkip navigationSearch JobsNIKE, INC. JOBSContract JobsJoin The Talent CommunityLife @ NikeOverviewBenefitsBrandsOverviewJordanConverseTeamsOverviewAdministrative SupportAdvanced InnovationAir Manufacturing InnovationAviationCommunicationsCustomer ServiceDesignDigitalFacilitiesFinance & AccountingGovernment & Public AffairsHuman ResourcesInsights & AnalyticsLegalManufacturing & EngineeringMarketingMerchandisingPlanningPrivacyProcurementProduct Creation, Development & ManagementRetail CorporateRetail StoresSalesSocial & Community ImpactSports MarketingStrategic PlanningSupply Chain, Distribution & LogisticsSustainabilityTechnologyLocationsOverviewNike WHQNike New York HQEHQ: Hilversum, The NetherlandsELC: Laakdal, BelgiumGreater China HQDiversity, Equity & InclusionOverviewMilitary InclusionDisability InclusionIndigenous InclusionInternshipsData & AnalyticsData Engineer, ITCKarnataka, IndiaBecome a Part of the NIKE, Inc. Team
# NIKE, Inc. does more than outfit the world’s best athletes. It is a place to explore potential, obliterate boundaries and push out the edges of what can be. The company looks for people who can grow, think, dream and create. Its culture thrives by embracing diversity and rewarding imagination. The brand seeks achievers, leaders and visionaries. At NIKE, Inc. it’s about each person bringing skills and passion to a challenging and constantly evolving game.WHO YOU’LL WORK WITHA data engineer will work in the Data and Artificial Intelligence organisation of Nike and will focus on building highly complex and performant data pipelines that'll drive Nike's data driven strategies for the future of sports.WHO WE ARE LOOKING FORIn this role, we are looking for self-driven individuals who have deep technical knowledge in the big data domain. This role requires the individual to be an excellent problem solver who'll design and implement complex data pipelines which solve business problems of Nike.The core competencies required for this role include -Bachelor’s degree in Computer Science Engineering2+ years of hands-on experience in Data Engineering fieldIn depth Big Data tech stack knowledgeExpertise in PySpark and SQLExpertise in Databricks, Snowflake and AirflowExcellent written and verbal communication skillsWHAT YOU’LL WORK ONAs a data engineer you'll be a key pillar of the data engineering team. You will collaborate closely with other engineers to deliver key changes to data pipelines that drive Nike's data strategyOn a day-to-day basis, you'll focus on -Building, enhancing, and troubleshooting complex data pipelinesCollaborating with product managers, engineers, analysts to build, enhance and troubleshoot data pipelinesCollaborate with senior, lead and principal engineers to define and implement quality standards across data pipelinesContribute towards the design and architecture of data pipelinesImplement data quality and reliability measures across data pipelinesNIKE, Inc. is a growth company that looks for team members to grow with it. Nike offers a generous total rewards package, casual work environment, a diverse and inclusive culture, and an electric atmosphere for professional development. No matter the location, or the role, every Nike employee shares one galvanizing mission: To bring inspiration and innovation to every athlete* in the world.NIKE, Inc. is committed to employing a diverse workforce. Qualified applicants will receive consideration without regard to race, color, religion, sex, national origin, age, sexual orientation, gender identity, gender expression, veteran status, or disability.How We HireAt NIKE, Inc. we promise to provide a premium, inclusive, compelling and authentic candidate experience. Delivering on this promise means we allow you to be at your best — and to do that, you need to understand how the hiring process works. Transparency is key.
#
# * This overview explains our hiring process for corporate roles. Note there may be different hiring steps involved for non-corporate roles.Start nowBenefitsWhether it’s transportation or financial health, we continually invest in our employees to help them achieve greatness — inside and outside of work. All who work here should be able to realize their full potential.Employee Assistance ProgramHolidaysMedical PlanPaid Time Off (PTO)Product DiscountsLearn moreGIFT CARDSPROMOTIONSFIND A STORESIGN UP FOR EMAILBECOME A MEMBERNIKE JOURNALSEND US FEEDBACKGET HELPGET HELPOrder StatusShipping and DeliveryReturnsPayment OptionsGift Cards BalanceContact UsABOUT NIKEABOUT NIKENewsCareersInvestorsPurposeSustainabilityUnited States© 2024 Nike, Inc. All Rights ReservedGuidesNike AdaptNike Air MaxNike FlyleatherNike ReactSpace HippieNike AirNike FlyEaseNike Free Nike VaporflyNike Air Force 1 Nike FlyknitNike JoyrideNike ZoomXTerms of SaleTerms of UseNike Privacy PolicyYour Privacy ChoicesCA Supply Chain Act

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'role': 'Data Engineer, ITC',
#  'experience': '2+ years',
#  'skills': ['Big Data tech stack knowledge',
#   'PySpark',
#   'SQL',
#   'Databricks',
#   'Snowflake',
#   'Airflow',
#   'Excellent written and verbal communication skills'],
#  'description': 'Building, enhancing, and troubleshooting complex data pipelines. Collaborating with product managers, engineers, analysts to build, enhance and troubleshoot data pipelines. Collaborate with senior, lead and principal engineers to define and implement quality standards across data pipelines. Contribute towards the design and architecture of data pipelines. Implement data quality and reliability measures across data pipelines.'}

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# 0                 https://example.com/react-portfolio
# 1               https://example.com/angular-portfolio
# 2                   https://example.com/vue-portfolio
# 3                https://example.com/python-portfolio
# 4                  https://example.com/java-portfolio
# 5               https://example.com/flutter-portfolio
# 6             https://example.com/wordpress-portfolio
# 7               https://example.com/magento-portfolio
# 8          https://example.com/react-native-portfolio
# 9                   https://example.com/ios-portfolio
# 10              https://example.com/android-portfolio
# 11       https://example.com/kotlin-android-portfolio
# 12           https://example.com/android-tv-portfolio
# 13               https://example.com/ios-ar-portfolio
# 14              https://example.com/xamarin-portfolio
# 15       https://example.com/kotlin-backend-portfolio
# 16  https://example.com/typescript-frontend-portfolio
# 17        https://example.com/full-stack-js-portfolio
# 18            https://example.com/ml-python-portfolio
# 19               https://example.com/devops-portfolio

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])

# %%
job = json_res

# %%
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/ios-portfolio'},
#   {'links': 'https://example.com/flutter-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/python-portfolio'}],
#  [{'links': 'https://example.com/magento-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}],
#  [{'links': 'https://example.com/flutter-portfolio'},
#   {'links': 'https://example.com/kotlin-android-portfolio'}],
#  [{'links': 'https://example.com/android-tv-portfolio'},
#   {'links': 'https://example.com/ios-ar-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/ios-ar-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/python-portfolio'}]]

# %%
job['skills']
# Out:
# ['Big Data tech stack knowledge',
#  'PySpark',
#  'SQL',
#  'Databricks',
#  'Snowflake',
#  'Airflow',
#  'Excellent written and verbal communication skills']

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Mohan, BDE at AtliQ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Expert Data Engineering Solutions for Your Business
#
# Dear Hiring Manager,
#
# I came across your job posting for a Data Engineer, ITC, and I'm excited to introduce you to AtliQ, an AI & Software Consulting company that can help you build, enhance, and troubleshoot complex data pipelines.
#
# With our expertise in Big Data tech stack, PySpark, SQL, Databricks, Snowflake, and Airflow, we can collaborate with your team to design and implement high-quality data pipelines that meet your business needs. Our team of experienced engineers can work closely with your product managers, engineers, and analysts to ensure seamless integration and troubleshooting of data pipelines.
#
# At AtliQ, we have a proven track record of delivering scalable, efficient, and reliable data engineering solutions. Our expertise in machine learning and Python can be leveraged to implement data quality and reliability measures across your data pipelines.
#
# I'd like to highlight some of our relevant portfolio work:
#
# * Machine Learning and Python expertise: https://example.com/ml-python-portfolio
# * Python-based solutions: https://example.com/python-portfolio
#
# These examples demonstrate our capabilities in building robust data engineering solutions that can help your business thrive.
#
# If you're looking for a trusted partner to help you build and enhance your data pipelines, I'd be happy to schedule a call to discuss how AtliQ can support your business goals.
#
# Please feel free to reply to this email or give me a call at your convenience.
#
# Best regards,
#
# Mohan
# Business Development Executive
# AtliQ
