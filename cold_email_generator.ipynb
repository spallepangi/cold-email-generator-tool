# %%
pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.3.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain) (1.4.39)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.10.5-cp39-cp39-win_amd64.whl.metadata (7.8 kB)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_core-0.3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.127-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain) (1.21.5)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\santhosh\appdata\roaming\python\python39\site-packages (from langchain) (2.29.0)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\santhosh\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (21.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.4.1-cp39-cp39-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.1.0-cp39-cp39-win_amd64.whl.metadata (5.1 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.12.1-cp39-cp39-win_amd64.whl.metadata (50 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.0->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting packaging<25,>=23.2 (from langchain-core<0.4.0,>=0.3.0->langchain)
#   Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting typing-extensions>=4.7 (from langchain-core<0.4.0,>=0.3.0->langchain)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting httpx<1,>=0.23.0 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.7-cp39-none-win_amd64.whl.metadata (51 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.23.4-cp39-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\santhosh\appdata\roaming\python\python39\site-packages (from requests<3,>=2->langchain) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\santhosh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\santhosh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\santhosh\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2022.9.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\santhosh\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Requirement already satisfied: anyio in c:\users\santhosh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.5.0)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sniffio in c:\users\santhosh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.0)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Downloading langchain-0.3.0-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 1.0/1.0 MB 9.5 MB/s eta 0:00:00
# Downloading aiohttp-3.10.5-cp39-cp39-win_amd64.whl (379 kB)
# Downloading langchain_core-0.3.5-py3-none-any.whl (399 kB)
# Downloading langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.127-py3-none-any.whl (291 kB)
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
# Downloading pydantic_core-2.23.4-cp39-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 1.9/1.9 MB 36.0 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl (12 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading frozenlist-1.4.1-cp39-cp39-win_amd64.whl (50 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading multidict-6.1.0-cp39-cp39-win_amd64.whl (28 kB)
# Downloading orjson-3.10.7-cp39-none-win_amd64.whl (137 kB)
# Downloading packaging-24.1-py3-none-any.whl (53 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading yarl-1.12.1-cp39-cp39-win_amd64.whl (111 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: typing-extensions, tenacity, packaging, orjson, jsonpointer, h11, frozenlist, annotated-types, aiohappyeyeballs, pydantic-core, multidict, jsonpatch, httpcore, aiosignal, yarl, pydantic, httpx, langsmith, aiohttp, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.3.0
#     Uninstalling typing_extensions-4.3.0:
#       Successfully uninstalled typing_extensions-4.3.0
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.0.1
#     Uninstalling tenacity-8.0.1:
#       Successfully uninstalled tenacity-8.0.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.1
#     Uninstalling packaging-23.1:
#       Successfully uninstalled packaging-23.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.7
#     Uninstalling pydantic-1.10.7:
#       Successfully uninstalled pydantic-1.10.7
# Successfully installed aiohappyeyeballs-2.4.0 aiohttp-3.10.5 aiosignal-1.3.1 annotated-types-0.7.0 frozenlist-1.4.1 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.0 langchain-core-0.3.5 langchain-text-splitters-0.3.0 langsmith-0.1.127 multidict-6.1.0 orjson-3.10.7 packaging-21.3 pydantic-2.9.2 pydantic-core-2.23.4 tenacity-8.5.0 typing-extensions-4.12.2 yarl-1.12.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.2.2 requires pyqt5<5.13, which is not installed.
# spyder 5.2.2 requires pyqtwebengine<5.13, which is not installed.
# fastapi 0.95.1 requires pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2, but you have pydantic 2.9.2 which is incompatible.
# python-dev-tools 2023.3.24 requires pip<23,>=22, but you have pip 24.2 which is incompatible.
# confection 0.0.4 requires pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4, but you have pydantic 2.9.2 which is incompatible.
# spacy 3.5.2 requires pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4, but you have pydantic 2.9.2 which is incompatible.
# thinc 8.1.9 requires pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4, but you have pydantic 2.9.2 which is incompatible.

# %%
pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Downloading langchain_groq-0.2.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting groq<1,>=0.4.1 (from langchain-groq)
#   Downloading groq-0.11.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-groq) (0.3.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\santhosh\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (3.5.0)
# Collecting distro<2,>=1.7.0 (from groq<1,>=0.4.1->langchain-groq)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\santhosh\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (0.27.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\santhosh\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (2.9.2)
# Requirement already satisfied: sniffio in c:\users\santhosh\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.2.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\santhosh\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq) (6.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq) (0.1.127)
# Collecting packaging<25,>=23.2 (from langchain-core<0.4,>=0.3->langchain-groq)
#   Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\santhosh\anaconda3\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-groq) (8.5.0)
# Requirement already satisfied: idna>=2.8 in c:\users\santhosh\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.3)
# Requirement already satisfied: certifi in c:\users\santhosh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2022.9.14)
# Requirement already satisfied: httpcore==1.* in c:\users\santhosh\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\santhosh\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\santhosh\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\santhosh\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq) (3.10.7)
# Requirement already satisfied: requests<3,>=2 in c:\users\santhosh\appdata\roaming\python\python39\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq) (2.29.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\santhosh\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\santhosh\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\santhosh\appdata\roaming\python\python39\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\santhosh\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3->langchain-groq) (1.26.11)
# Downloading langchain_groq-0.2.0-py3-none-any.whl (14 kB)
# Downloading groq-0.11.0-py3-none-any.whl (106 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached packaging-24.1-py3-none-any.whl (53 kB)
# Installing collected packages: packaging, distro, groq, langchain-groq
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# Successfully installed distro-1.9.0 groq-0.11.0 langchain-groq-0.2.0 packaging-24.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.2.2 requires pyqt5<5.13, which is not installed.
# spyder 5.2.2 requires pyqtwebengine<5.13, which is not installed.
# python-dev-tools 2023.3.24 requires pip<23,>=22, but you have pip 24.2 which is incompatible.
# spacy 3.5.2 requires pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4, but you have pydantic 2.9.2 which is incompatible.
# thinc 8.1.9 requires pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4, but you have pydantic 2.9.2 which is incompatible.

# %%
pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.5.7-py3-none-any.whl.metadata (6.8 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.2.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (2.9.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Downloading chroma_hnswlib-0.7.6-cp39-cp39-win_amd64.whl.metadata (262 bytes)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting numpy>=1.22.5 (from chromadb)
#   Downloading numpy-2.0.2-cp39-cp39-win_amd64.whl.metadata (59 kB)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.6.6-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.19.2-cp39-cp39-win_amd64.whl.metadata (4.7 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (0.13.3)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting tqdm>=4.65.0 (from chromadb)
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Downloading grpcio-1.66.1-cp39-cp39-win_amd64.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.2.0-cp39-abi3-win_amd64.whl.metadata (9.9 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (6.0)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.0.1-cp39-cp39-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (3.10.7)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\santhosh\appdata\roaming\python\python39\site-packages (from chromadb) (13.3.5)
# Requirement already satisfied: packaging>=19.1 in c:\users\santhosh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.1.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\santhosh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\santhosh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (4.11.3)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\santhosh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.38.6-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: anyio in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.5.0)
# Requirement already satisfied: certifi in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2022.9.14)
# Requirement already satisfied: httpcore==1.* in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.5)
# Requirement already satisfied: idna in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.3)
# Requirement already satisfied: sniffio in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\santhosh\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.16.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests in c:\users\santhosh\appdata\roaming\python\python39\site-packages (from kubernetes>=28.1.0->chromadb) (2.29.0)
# Requirement already satisfied: requests-oauthlib in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.11)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.7.tar.gz (3.2 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [1 lines of output]
#   ERROR: Can not execute `setup.py` since setuptools is not available in the build environment.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
pip install --upgrade setuptools
# Out:
# Requirement already satisfied: setuptools in c:\users\santhosh\anaconda3\lib\site-packages (75.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade wheel
# Out:
# Requirement already satisfied: wheel in c:\users\santhosh\anaconda3\lib\site-packages (0.44.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install chromadb
# Out:
# Collecting chromadb
#   Using cached chromadb-0.5.7-py3-none-any.whl.metadata (6.8 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.2.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (2.9.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Using cached chroma_hnswlib-0.7.6-cp39-cp39-win_amd64.whl.metadata (262 bytes)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Using cached fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting numpy>=1.22.5 (from chromadb)
#   Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl.metadata (59 kB)
# Collecting posthog>=2.4.0 (from chromadb)
#   Using cached posthog-3.6.6-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.19.2-cp39-cp39-win_amd64.whl.metadata (4.7 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Using cached opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.27.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (0.13.3)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting tqdm>=4.65.0 (from chromadb)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Using cached grpcio-1.66.1-cp39-cp39-win_amd64.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.2.0-cp39-abi3-win_amd64.whl.metadata (9.9 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Using cached typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (6.0)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-5.0.1-cp39-cp39-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (3.10.7)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\santhosh\appdata\roaming\python\python39\site-packages (from chromadb) (13.3.5)
# Requirement already satisfied: packaging>=19.1 in c:\users\santhosh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.1.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\santhosh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\santhosh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (4.11.3)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\santhosh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi>=0.95.2->chromadb)
#   Using cached starlette-0.38.6-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: anyio in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.5.0)
# Requirement already satisfied: certifi in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2022.9.14)
# Requirement already satisfied: httpcore==1.* in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.5)
# Requirement already satisfied: idna in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.3)
# Requirement already satisfied: sniffio in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\santhosh\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.16.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests in c:\users\santhosh\appdata\roaming\python\python39\site-packages (from kubernetes>=28.1.0->chromadb) (2.29.0)
# Requirement already satisfied: requests-oauthlib in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.11)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.7.tar.gz (3.2 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [1 lines of output]
#   ERROR: Can not execute `setup.py` since setuptools is not available in the build environment.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import chromadb

client = chromadb.Client()
collection = client.create_collection(name="my_collection")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24196\4272820834.py in <module>
# ----> 1 import chromadb
#       2
#       3 client = chromadb.Client()
#       4 collection = client.create_collection(name="my_collection")
#
# ModuleNotFoundError: No module named 'chromadb'

# %%
pip install ez_setup
# Out:
# Collecting ez_setup
#   Downloading ez_setup-0.9.tar.gz (6.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [1 lines of output]
#   ERROR: Can not execute `setup.py` since setuptools is not available in the build environment.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
easy_install -U setuptools
# Out:
#   File "C:\Users\Santhosh\AppData\Local\Temp\ipykernel_24196\264745531.py", line 1
#     easy_install -U setuptools
#                     ^
# SyntaxError: invalid syntax

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\santhosh\anaconda3\lib\site-packages (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install chromadb
# Out:
# Collecting chromadbNote: you may need to restart the kernel to use updated packages.
#
#   Using cached chromadb-0.5.7-py3-none-any.whl.metadata (6.8 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.2.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (2.9.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Using cached chroma_hnswlib-0.7.6-cp39-cp39-win_amd64.whl.metadata (262 bytes)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Using cached fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting numpy>=1.22.5 (from chromadb)
#   Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl.metadata (59 kB)
# Collecting posthog>=2.4.0 (from chromadb)
#   Using cached posthog-3.6.6-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.19.2-cp39-cp39-win_amd64.whl.metadata (4.7 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Using cached opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.27.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (0.13.3)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting tqdm>=4.65.0 (from chromadb)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Using cached grpcio-1.66.1-cp39-cp39-win_amd64.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.2.0-cp39-abi3-win_amd64.whl.metadata (9.9 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Using cached typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (6.0)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-5.0.1-cp39-cp39-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (3.10.7)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\santhosh\anaconda3\lib\site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\santhosh\appdata\roaming\python\python39\site-packages (from chromadb) (13.3.5)
# Requirement already satisfied: packaging>=19.1 in c:\users\santhosh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.1.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\santhosh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\santhosh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (4.11.3)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\santhosh\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi>=0.95.2->chromadb)
#   Using cached starlette-0.38.6-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: anyio in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.5.0)
# Requirement already satisfied: certifi in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2022.9.14)
# Requirement already satisfied: httpcore==1.* in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.5)
# Requirement already satisfied: idna in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.3)
# Requirement already satisfied: sniffio in c:\users\santhosh\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\santhosh\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.16.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests in c:\users\santhosh\appdata\roaming\python\python39\site-packages (from kubernetes>=28.1.0->chromadb) (2.29.0)
# Requirement already satisfied: requests-oauthlib in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\santhosh\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.11)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.7.tar.gz (3.2 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [1 lines of output]
#   ERROR: Can not execute `setup.py` since setuptools is not available in the build environment.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
